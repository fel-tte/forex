# %% [markdown]
# # Lay 1 cap tien te

# %%
import sys
sys.path.append('../Common/')

import CommonMT5DWH
import MetaTrader5 as mt5

from datetime import datetime, timedelta

symbol = 'EURUSD.sml'
# from_date_str = (datetime.now() - timedelta(days=15000)).strftime('%Y-%m-%d')
# from_date = datetime.strptime(from_date_str, '%Y-%m-%d')
# to_date_str = (datetime.now() + timedelta(days=0)).strftime('%Y-%m-%d')
# to_date = datetime.strptime(to_date_str, '%Y-%m-%d')
from_date = datetime.strptime('1970-01-05', '%Y-%m-%d')
to_date = datetime.strptime('2025-04-18', '%Y-%m-%d')

timeframe = mt5.TIMEFRAME_D1  # 1 ngày

data = CommonMT5DWH.CommonMT5DWH.loaddataMT5_FromTo_List_Ext(symbol, from_date, to_date, timeframe)

data
# Out:
# Khởi tạo MT5 không thành công
