# %% [markdown]
# # Cho lich chay 1 phut 1 lan, quet thi truong lay du lieu cua gia vang tren san FX va in ra du lieu

# %% [markdown]
# Quet: Dung cac ham trong Common

# %%
def scan_market():
	import sys
	sys.path.append("../Common")
	import MetaTrader5 as mt5
	import TradeMT5

	data = TradeMT5.TradeMT5.getData_MT5(symbol="XAUUSD.sml", timeframe=mt5.TIMEFRAME_M1, limit=100)

	print(data)

# %%
import schedule

schedule.every(1).minute.at(":00").do(scan_market)

while True:
	schedule.run_pending()
# Out:
#                          Open      High       Low     Close  Volume  spread  \
# time
# 2025-10-08 15:46:00  4034.990  4035.615  4034.370  4034.880     252     220
# 2025-10-08 15:47:00  4034.900  4037.240  4034.710  4036.695     293     280
# 2025-10-08 15:48:00  4036.690  4038.155  4036.210  4038.130     419     160
# 2025-10-08 15:49:00  4038.145  4038.660  4036.515  4037.125     410     100
# 2025-10-08 15:50:00  4037.130  4037.140  4035.760  4035.830     369     160
# ...                       ...       ...       ...       ...     ...     ...
# 2025-10-08 17:21:00  4040.440  4041.975  4039.025  4041.460     456     300
# 2025-10-08 17:22:00  4041.435  4041.890  4040.285  4041.425     395     230
# 2025-10-08 17:23:00  4041.440  4042.000  4039.825  4039.835     465     230
# 2025-10-08 17:24:00  4039.860  4040.715  4037.810  4038.215     526     280
# 2025-10-08 17:25:00  4038.290  4042.030  4038.265  4041.930     556     240
#
#                      real_volume
# time
# ...
