# %%
api_key = 'mrDMHJROc4a5MBKsYAL3Zf8gqTU3e3tMq6JTNu8RyIocFwqnt8DSz6kIdSvdHGpD' # K9
api_secret = 's82XF6mVbHmHmJGJNIDEyPmbN8AFjE1AdZmUbjK0TaKk6uUGivmsc4A7BqnGeJUI' # K9

# %%
# Hàm để đặt một lệnh mua
import requests
import os
from binance.client import Client
from binance.enums import *

def orderCRTOFT(data):
    
    # Lấy dữ liệu từ từ điển
    buy_signal = data['Buy_Signal']    
    sell_signal = data['Sell_Signal']
    symbol = data['Symbol']
    insertdate = data['Insertdate']
    
    order = None

    # Khởi tạo client
    client = Client(api_key, api_secret)

    quantity = 0.015
    leverage = 11  # Đòn bẩy

    # Thay đổi đòn bẩy
    client.futures_change_leverage(symbol=symbol, leverage=leverage)
    # Thay đổi loại ký quỹ chéo (Cross) sang ký quỹ riêng lẻ (ISOLATED)
    # client.futures_change_margin_type(symbol=symbol, marginType='ISOLATED')

    # Lấy thông tin giá gần nhất của ETHUSDT
    ethusdt_price = client.get_symbol_ticker(symbol=symbol)
    entry_price = ethusdt_price["price"]

    # Chuyển đổi entry_price sang float
    entry_price = float(entry_price)
    
    allowed_precision = 2  # Giả sử độ chính xác tối đa là 6 chữ số thập phân

    order = None

    try:
        if buy_signal == 'True':
            print("Placing a BUY market order.")
            # Đặt Take Profit và Stop Loss (cần tính toán dựa trên chiến lược)
            take_profit = round(entry_price * 1.01, allowed_precision)
            stop_loss = round(entry_price * 0.98, allowed_precision)
            
            # Đặt lệnh mua
            buy_order = client.futures_create_order(
                symbol=symbol,
                side=SIDE_BUY,
                type=ORDER_TYPE_MARKET,
                quantity=quantity
            )           
            print("Buy order placed successfully:", buy_order)
            
            print("Placing a TAKE PROFIT market order.")
            tp_order = client.futures_create_order(
                symbol=symbol,
                side=SIDE_SELL,
                type=FUTURE_ORDER_TYPE_TAKE_PROFIT_MARKET ,
                timeInForce=TIME_IN_FORCE_GTC,
                quantity=quantity,
                stopPrice=take_profit,
                reduceOnly='true'
            )
            print("Take profit order placed successfully:", tp_order)

            print("Placing a STOP LOSS stop market order.")
            sl_order = client.futures_create_order(
                symbol=symbol,
                side=SIDE_SELL,
                type=FUTURE_ORDER_TYPE_STOP_MARKET,
                quantity=quantity,
                stopPrice=stop_loss,
                reduceOnly='true'
            )
            print("Stop loss order placed successfully:", sl_order)

        elif sell_signal == 'True':
            print("Placing a SELL market order.")
            # Đặt Take Profit và Stop Loss (cần tính toán dựa trên chiến lược)
            take_profit = round(entry_price * 0.99, allowed_precision)
            stop_loss = round(entry_price * 1.02, allowed_precision)
            
            # Đặt lệnh bán
            sell_order = client.futures_create_order(
                symbol=symbol,
                side=SIDE_SELL,
                type=ORDER_TYPE_MARKET,
                quantity=quantity
            )            
            print("Sell order placed successfully:", sell_order)
           
            print("Placing a TAKE PROFIT market order.")
            tp_order = client.futures_create_order(
                symbol=symbol,
                side=SIDE_BUY,
                type=FUTURE_ORDER_TYPE_TAKE_PROFIT_MARKET,
                timeInForce=TIME_IN_FORCE_GTC,
                quantity=quantity,
                stopPrice=take_profit,
                reduceOnly='true'
            )
            print("Take profit order placed successfully:", tp_order)

            print("Placing a STOP LOSS stop market order.")
            sl_order = client.futures_create_order(
                symbol=symbol,
                side=SIDE_BUY,
                type=FUTURE_ORDER_TYPE_STOP_MARKET,
                quantity=quantity,
                stopPrice=stop_loss,
                reduceOnly='true'
            )
            print("Stop loss order placed successfully:", sl_order)

    except Exception as e:
        print(f"An error occurred: {e}")

# %%
import redis
from datetime import datetime, timedelta

def entryCryptoFT(hash):
    # Xử lý dữ liệu ở đây
    print("Dữ liệu đã được xử lý", datetime.now())

    # Tạo kết nối Redis
    r = redis.Redis(host='localhost', port=6379, db=0)

    # Hash key
    hash_key = hash

    # Đọc dữ liệu từ hash
    data = r.hgetall(hash_key)
    
    if data:
        # Chuyển đổi dữ liệu từ bytes sang chuỗi nếu cần
        data = {key.decode('utf-8'): value.decode('utf-8') for key, value in data.items()}
        # Xử lý dữ liệu
        orderCRTOFT(data)
        # Xóa hash sau khi xử lý
        r.delete(hash_key)
        print(f"Hash '{hash_key}' đã được xóa khỏi Redis.")
    else:
        print(f"Không tìm thấy dữ liệu cho hash '{hash_key}'.")

# %%
from datetime import datetime, timedelta
import schedule
import time

def schedule_CryptoFT():
    entryCryptoFT('OG_CRTO_Arima, Momentum, RSI')

# Lên lịch hàm scan_market để chạy mỗi 15 phút
schedule.every(10).seconds.do(schedule_CryptoFT)

while True:
    schedule.run_pending()  # Hàm này được gọi liên tục để kiểm tra xem có công việc nào đã đến thời gian cần thực hiện hay không
    time.sleep(10)
# Out:
# Dữ liệu đã được xử lý 2025-03-20 21:39:44.433954
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20656\208180594.py in ?()
#       8 # Lên lịch hàm scan_market để chạy mỗi 15 phút
#       9 schedule.every(10).seconds.do(schedule_CryptoFT)
#      10
#      11 while True:
# ---> 12     schedule.run_pending()  # Hàm này được gọi liên tục để kiểm tra xem có công việc nào đã đến thời gian cần thực hiện hay không
#      13     time.sleep(10)
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\schedule\__init__.py in ?()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\schedule\__init__.py in ?(self)
#      97         between but only once.
#      98         """
#      99         runnable_jobs = (job for job in self.jobs if job.should_run)
#     100         for job in sorted(runnable_jobs):
# --> 101             self._run_job(job)
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\schedule\__init__.py in ?(self, job)
#     172     def _run_job(self, job: "Job") -> None:
# --> 173         ret = job.run()
#     174         if isinstance(ret, CancelJob) or ret is CancelJob:
#     175             self.cancel_job(job)
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\schedule\__init__.py in ?(self)
#     687             logger.debug("Cancelling job %s", self)
#     688             return CancelJob
#     689
#     690         logger.debug("Running job %s", self)
# --> 691         ret = self.job_func()
#     692         self.last_run = datetime.datetime.now()
#     693         self._schedule_next_run()
#     694
#
# ~\AppData\Local\Temp\ipykernel_20656\208180594.py in ?()
#       5 def schedule_CryptoFT():
# ----> 6     entryCryptoFT('OG_CRTO_Arima, Momentum, RSI')
#
# ~\AppData\Local\Temp\ipykernel_20656\1927202290.py in ?(hash)
#      17     if data:
#      18         # Chuyển đổi dữ liệu từ bytes sang chuỗi nếu cần
#      19         data = {key.decode('utf-8'): value.decode('utf-8') for key, value in data.items()}
#      20         # Xử lý dữ liệu
# ---> 21         orderCRTOFT(data)
#      22         # Xóa hash sau khi xử lý
#      23         r.delete(hash_key)
#      24         print(f"Hash '{hash_key}' đã được xóa khỏi Redis.")
#
# ~\AppData\Local\Temp\ipykernel_20656\1979916306.py in ?(data)
#      20     quantity = 0.015
#      21     leverage = 11  # Đòn bẩy
#      22
#      23     # Thay đổi đòn bẩy
# ---> 24     client.futures_change_leverage(symbol=symbol, leverage=leverage)
#      25     # Thay đổi loại ký quỹ chéo (Cross) sang ký quỹ riêng lẻ (ISOLATED)
#      26     # client.futures_change_margin_type(symbol=symbol, marginType='ISOLATED')
#      27
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\binance\client.py in ?(self, **params)
#    7814
#    7815         https://binance-docs.github.io/apidocs/futures/en/#change-initial-leverage-trade
#    7816
#    7817         """
# -> 7818         return self._request_futures_api("post", "leverage", True, data=params)
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\binance\client.py in ?(self, method, path, signed, version, **kwargs)
#     479     ) -> Dict:
#     480         version = self._get_version(version, **kwargs)
#     481         uri = self._create_futures_api_uri(path, version)
#     482
# --> 483         return self._request(method, uri, signed, True, **kwargs)
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\binance\client.py in ?(self, method, uri, signed, force_params, **kwargs)
#     447     ):
#     448         kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     449
#     450         self.response = getattr(self.session, method)(uri, **kwargs)
# --> 451         return self._handle_response(self.response)
#
# c:\Users\PCDTT\AppData\Local\Programs\Python\Python311\Lib\site-packages\binance\client.py in ?(response)
#     456         Raises the appropriate exceptions when necessary; otherwise, returns the
#     457         response.
#     458         """
#     459         if not (200 <= response.status_code < 300):
# --> 460             raise BinanceAPIException(response, response.status_code, response.text)
#     461         try:
#     462             return response.json()
#     463         except ValueError:
#
# BinanceAPIException: APIError(code=-2015): Invalid API-key, IP, or permissions for action, request ip: 183.80.201.204
