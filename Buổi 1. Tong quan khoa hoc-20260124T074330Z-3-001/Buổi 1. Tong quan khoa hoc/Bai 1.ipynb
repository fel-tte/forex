# %% [markdown]
# # In ra Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # In ra Hello World 2024

# %%
print('Hello World 2024-2025')
# Out:
# Hello World 2024-2025

# %% [markdown]
# Ghi chu

# %%
print(123)
# Out:
# 123

# %% [markdown]
# 23/05/2024
