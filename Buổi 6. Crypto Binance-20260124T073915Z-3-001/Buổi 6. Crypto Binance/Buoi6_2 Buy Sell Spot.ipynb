# %% [markdown]
# # Khai bao cac thu vien

# %%
import ccxt
import pandas as pd

# %% [markdown]
# # Khai API Key va Secret Key duoc lay tu Binance.com

# %%
# Da lay API va khai bao Enable FUTURE + Whitelist Coin + Trust IP 
api_key = '8aGUrrY3pNZRwno6UbJQILaoJdXn5yvNl5AM1jgZbTXP28eOpQavyhxqXt345i9q' # K13
secret_key = 'o31ZS7A6BTEld143QfZNHIlh95ENbitOs8Inw8jIq6Rl1IGDLwDZsjlhiE2DFWgE' # K13

# %% [markdown]
# # Spot: Mua thi truong

# %%
import ccxt

# Khởi tạo kết nối với Binance Spot API
exchange_spot = ccxt.binance(
	{
		'apiKey': api_key,
		'secret': secret_key
		# 'enableRateLimit': True,  # Giới hạn tốc độ gửi yêu cầu
	}
)

# Thực hiện lệnh mua giá thị trường cho cặp giao dịch BTC/USDT với số lượng 1 BTC
symbol_spot = 'NEARUSDT' # Phai khai bao trong whitelist
# side_spot = 'buy'  # Mua
quantity_spot = 2.0  # Số lượng NEAR mua

# {"code":-1013,"msg":"Filter failure: NOTIONAL"} là sao hả thầy
# Lỗi này thường xảy ra khi giá trị giao dịch không đáp ứng yêu cầu tối thiểu của sàn giao dịch.
# Để khắc phục, bạn cần đảm bảo rằng giá trị giao dịch (giá * số lượng) đáp ứng yêu cầu tối thiểu của Binance.

# order_type_spot = 'market'  # Loại lệnh là market order

# Thực hiện lệnh mua giá thị trường
order_spot = exchange_spot.create_market_buy_order(symbol_spot, quantity_spot) #

# In thông tin đơn hàng mua giá thị trường
print("Market Order:")
print(order_spot)

# %% [markdown]
# # Spot: Ban thi truong

# %% [markdown]
# #### Khong Kiem tra tai san

# %%
import ccxt

# Khởi tạo kết nối với Binance Spot API
exchange = ccxt.binance({
	'apiKey': api_key,  
	'secret': secret_key  
})

# Chọn cặp giao dịch bạn quan tâm
symbol = 'NEARUSDT'

order = exchange.create_market_sell_order(symbol, 3) # Co 2, ban 3
print("Market Sell Order:")
print(order)

# %% [markdown]
# #### Kiem tra so luong coin co trong tai khoan

# %%
import ccxt

# Khởi tạo kết nối với Binance Spot API
exchange = ccxt.binance({
	'apiKey': api_key,  
	'secret': secret_key  
})

# Chọn cặp giao dịch bạn quan tâm
symbol = 'NEARUSDT'

# Lấy thông tin tài khoản
account_info = exchange.fetch_balance()

account_info
# Out:
# {'info': {'makerCommission': '10',
#   'takerCommission': '10',
#   'buyerCommission': '0',
#   'sellerCommission': '0',
#   'commissionRates': {'maker': '0.00100000',
#    'taker': '0.00100000',
#    'buyer': '0.00000000',
#    'seller': '0.00000000'},
#   'canTrade': True,
#   'canWithdraw': True,
#   'canDeposit': True,
#   'brokered': False,
#   'requireSelfTradePrevention': False,
#   'preventSor': False,
#   'updateTime': '1758895350055',
#   'accountType': 'SPOT',
#   'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#    {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#    {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#    {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#    {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#    {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#    {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
print(type(account_info))
account_info

# %%
# Lấy số lượng BTC hiện có trong tài khoản
asset_balance = account_info['total']['NEAR']
asset_balance
# Out:
# 2.084

# %% [markdown]
# # Viet lai ham lay so luong coin

# %%
import ccxt
# Viet ham lay balance cua 1 coin
def get_balance(coin):
	exchange = ccxt.binance({
	'apiKey': api_key,  
	'secret': secret_key  
		})
	# account_info = exchange.fetch_balance()
	account_info = exchange.fetch_balance()
	return account_info['total'][coin]

get_balance('NEAR')
# Out:
# 2.084

# %% [markdown]
# #### Ban tai san

# %%
# order = exchange.create_market_sell_order(symbol, asset_balance)
# print("Market Sell Order:")
# print(order)

# %% [markdown]
# # Truoc khi ban thi kiem tra so luong tai san dư thì mới bán, còn nếu ko dư thì bán đúng số tài sản đang có

# %%
import ccxt

# Khởi tạo kết nối với Binance Spot API
exchange = ccxt.binance({
	'apiKey': api_key,  
	'secret': secret_key  
})

# Chọn cặp giao dịch bạn quan tâm
symbol = 'NEARUSDT'

# Lấy thông tin tài khoản
account_info = exchange.fetch_balance()

# Lấy số lượng BTC hiện có trong tài khoản
asset_balance = account_info['total']['NEAR']

# Thực hiện lệnh bán giá thị trường
if asset_balance >= 1: # Tai san duong
	order = exchange.create_market_sell_order(symbol, asset_balance)
	print("Market Sell Order:")
	print(order)
else:
	print("Không có NEAR trong tài khoản.")
# Out:
# Không có NEAR trong tài khoản.

# %% [markdown]
# #### Ban so luong tuy chon

# %%
order = exchange.create_market_sell_order(symbol, 1)
print("Market Sell Order:")
print(order)

# %% [markdown]
# # Kiem tra lich su mua ban

# %%
import ccxt
from datetime import datetime

# Khởi tạo kết nối với Binance Spot API bằng API Key và Secret Key
exchange = ccxt.binance({
	'apiKey': api_key,
	'secret': secret_key,
})

symbol = 'NEARUSDT' # Kiem tra doi voi coin nay

# Lấy lịch sử giao dịch mua bán
trade_history = exchange.fetch_my_trades(symbol)
print(trade_history)

##########################################################################
i = 0
# In lịch sử giao dịch
for trade in trade_history:
	trade['timestamp'] = datetime.fromtimestamp(trade['timestamp'] / 1000)  # Chia cho 1000 để chuyển từ millisecond thành giây
	print(f"ID: {trade['id']}, Cặp giao dịch: {trade['symbol']}, Loại: {trade['side']}, Giá: {trade['price']}, Số lượng: {trade['amount']}, Thời gian: {trade['timestamp']}")
# Out:
# [{'info': {'symbol': 'NEARUSDT', 'id': '209629441', 'orderId': '3113614807', 'orderListId': '-1', 'price': '5.17500000', 'qty': '1.00000000', 'quoteQty': '5.17500000', 'commission': '0.00100000', 'commissionAsset': 'NEAR', 'time': '1727793071500', 'isBuyer': True, 'isMaker': False, 'isBestMatch': True}, 'timestamp': 1727793071500, 'datetime': '2024-10-01T14:31:11.500Z', 'symbol': 'NEAR/USDT', 'id': '209629441', 'order': '3113614807', 'type': None, 'side': 'buy', 'takerOrMaker': 'taker', 'price': 5.175, 'amount': 1.0, 'cost': 5.175, 'fee': {'currency': 'NEAR', 'cost': 0.001}, 'fees': [{'currency': 'NEAR', 'cost': 0.001}]}, {'info': {'symbol': 'NEARUSDT', 'id': '209641453', 'orderId': '3113694288', 'orderListId': '-1', 'price': '5.14700000', 'qty': '1.00000000', 'quoteQty': '5.14700000', 'commission': '0.00100000', 'commissionAsset': 'NEAR', 'time': '1727793584254', 'isBuyer': True, 'isMaker': False, 'isBestMatch': True}, 'timestamp': 1727793584254, 'datetime': '2024-10-01T14:39:44.254
# ...

# %%
0.008/2*100

# %% [markdown]
# # Buy

# %%
# Buy limit
