# %% [markdown]
# ### Bai tap: Gia du doan nam tren gia thuc te va MA10 > MA20 => Mua
# ### Bai tap: Gia du doan nam tren gia thuc te va MA10 < MA20 => Ban
# ### Tren Crypto
# ### => OG

# %% [markdown]
# # Load data

# %%
import sys
import os
sys.path.append("../..")
