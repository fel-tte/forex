# %% [markdown]
# # Doc Redis DB=5

# %%
# import redis 
# import pandas as pd

# # Tạo kết nối Redis
# r = redis.Redis(host='localhost', port=6379, db=5)

# # Hash key
# hash_key = 'OG_FX_MA10, MA20'

# # Đọc dữ liệu từ hash
# data = r.hgetall(hash_key)
# print('JSON:', data)

# if data:
# 	# Chuyển đổi dữ liệu từ bytes sang chuỗi nếu cần
# 	data = {key.decode('utf-8'): value.decode('utf-8') for key, value in data.items()}
# 	print('Dictionary:', data)
# 	# dataFrame = pd.DataFrame([data])
# 	# print('DataFrame:', dataFrame)

# %% [markdown]
# # Ham vao lenh

# %%
# Hàm để đặt một lệnh mua
import MetaTrader5 as mt5

def orderSendForex(data):
    # Lấy dữ liệu từ từ điển
    # datetime = data['Datetime']
    open_price = data['Open']
    close_price = data['Close']
    volume = data['Volume']
    buy_signal = data['Buy_Signal']    
    sell_signal = data['Sell_Signal']
    symbol = data['Symbol'] 
    insertdate = data['Insertdate']
    
    login = 6338576 # OANDa
    password = '123456Qaz1!'
    server = 'OANDA-Demo-1'    
      
    if not mt5.initialize(login=login, password=password, server=server): # XS           
        print("Initialize() failed, error code =", mt5.last_error())
        quit()
    else:
        if(buy_signal == 'True'):
            lot = 0.01  # Số lượng lô mà bạn muốn mua
            if not mt5.symbol_select(symbol, True): # 
                print(f"Failed to select {symbol}, error code =", mt5.last_error())
                return

            symbol_info = mt5.symbol_info(symbol)
            if symbol_info is None:
                print(f"{symbol} not found")
                return
            
            point = symbol_info.point
            price = mt5.symbol_info_tick(symbol).ask
            deviation = 20  # Độ lệch giá cho phép

            request = {
                "action": mt5.TRADE_ACTION_DEAL,
                "symbol": symbol,
                "volume": lot,
                "type": mt5.ORDER_TYPE_BUY,
                "price": price,
                "sl": price - 400 * point,  # Lệnh dừng lỗ (Stop Loss)
                "tp": price + 200 * point,  # Lệnh chốt lời (Take Profit)
                "deviation": deviation,
                "magic": 234000,
                "comment": "python script open",
                "type_time": mt5.ORDER_TIME_GTC,
                # "type_filling": mt5.ORDER_FILLING_IOC,
                "type_filling": mt5.ORDER_FILLING_FOK,
                
            }

            result = mt5.order_send(request)
            if result.retcode != mt5.TRADE_RETCODE_DONE:
                print("Failed to send order :", result.retcode, result._asdict())
            else:
                print("Order placed BUY successfully!", result)

            # Đóng kết nối với MT5
            mt5.shutdown()
        elif (sell_signal == 'True'):
            lot = 0.01  # Số lượng lô bạn muốn bán
            if not mt5.symbol_select(symbol, True):
                print(f"Failed to select {symbol}, error code =", mt5.last_error())
                return

            symbol_info = mt5.symbol_info(symbol)
            if symbol_info is None:
                print(f"{symbol} not found")
                return
            
            point = symbol_info.point
            price = mt5.symbol_info_tick(symbol).bid  # Sử dụng giá bid cho lệnh bán
            deviation = 20  # Độ lệch giá cho phép

            request = {
                "action": mt5.TRADE_ACTION_DEAL,
                "symbol": symbol,
                "volume": lot,
                "type": mt5.ORDER_TYPE_SELL,
                "price": price,
                "sl": price + 400 * point,  # Lệnh dừng lỗ (Stop Loss) cho lệnh bán
                "tp": price - 200 * point,  # Lệnh chốt lời (Take Profit) cho lệnh bán
                "deviation": deviation,
                "magic": 234000,
                "comment": "python script open",
                "type_time": mt5.ORDER_TIME_GTC,
                # "type_filling": mt5.ORDER_FILLING_IOC,
                "type_filling": mt5.ORDER_FILLING_FOK,
                # ORDER_FILLING_RETURN 
            }

            result = mt5.order_send(request)
            if result.retcode != mt5.TRADE_RETCODE_DONE:
                print("Failed to send order :", result.retcode, result._asdict())
            else:
                print("Order placed SELL successfully!", result)

            # Đóng kết nối với MT5
            mt5.shutdown()

# %%
import redis

def entryForex(hash):
    # Xử lý dữ liệu ở đây
    print("Dữ liệu đã được xử lý")

    # Tạo kết nối Redis
    r = redis.Redis(host='localhost', port=6379, db=5)

    # Hash key
    hash_key = hash

    # Đọc dữ liệu từ hash
    data = r.hgetall(hash_key)
    
    if data:
        # Chuyển đổi dữ liệu từ bytes sang chuỗi nếu cần
        data = {key.decode('utf-8'): value.decode('utf-8') for key, value in data.items()}
        # Xử lý dữ liệu
        orderSendForex(data)
        # Xóa hash sau khi xử lý
        r.delete(hash_key)
        print(f"Hash '{hash_key}' đã được xóa khỏi Redis.")
    else:
        print(f"Không tìm thấy dữ liệu cho hash '{hash_key}'.")

# %% [markdown]
# # Schedule

# %%
from datetime import datetime, timedelta
import schedule
import time

def schedule_entryForex():   
    entryForex('OG_FX_MA10, MA20')

# Lên lịch hàm scan_market để chạy mỗi 15 phút
schedule.every(10).seconds.do(schedule_entryForex)

while True:
    schedule.run_pending()  # Hàm này được gọi liên tục để kiểm tra xem có công việc nào đã đến thời gian cần thực hiện hay không
# Out:
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19413762, order=20988438, volume=0.01, price=20788.4, bid=20788.4, ask=20790.2, comment='Request executed', request_id=1683350112, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20787.9, stoplimit=0.0, sl=20827.9, tp=20767.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19413831, order=20988509, volume=0.01, price=20785.9, bid=20785.9, ask=20787.7, comment='Request executed', request_id=1683350113, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20787.2, stoplimit=0.0, sl=20827.2, tp=20767.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19413926, order=20988623, volume=0.01, price=20745.7, bid=20745.7, ask=20747.5, comment='Request executed', request_id=1683350114, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20747.2, stoplimit=0.0, sl=20787.2, tp=20727.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19413982, order=20988680, volume=0.01, price=20738.2, bid=20738.2, ask=20740.3, comment='Request executed', request_id=1683350115, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20742.7, stoplimit=0.0, sl=20782.7, tp=20722.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414097, order=20988815, volume=0.01, price=20760.4, bid=20760.4, ask=20762.2, comment='Request executed', request_id=1683350116, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20761.4, stoplimit=0.0, sl=20801.4, tp=20741.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414143, order=20988884, volume=0.01, price=20752.4, bid=20752.4, ask=20754.5, comment='Request executed', request_id=1683350117, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20752.4, stoplimit=0.0, sl=20792.4, tp=20732.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414182, order=20988923, volume=0.01, price=20752.7, bid=20752.7, ask=20754.5, comment='Request executed', request_id=1683350118, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20753.4, stoplimit=0.0, sl=20793.4, tp=20733.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414315, order=20989077, volume=0.01, price=20733.4, bid=20733.4, ask=20735.2, comment='Request executed', request_id=1683350119, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20733.2, stoplimit=0.0, sl=20773.2, tp=20713.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414357, order=20989116, volume=0.01, price=20718.9, bid=20718.9, ask=20720.7, comment='Request executed', request_id=1683350120, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20717.2, stoplimit=0.0, sl=20757.2, tp=20697.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414458, order=20989217, volume=0.01, price=20713.4, bid=20713.4, ask=20715.2, comment='Request executed', request_id=1683350121, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20713.2, stoplimit=0.0, sl=20753.2, tp=20693.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414485, order=20989244, volume=0.01, price=20694.2, bid=20694.2, ask=20696.0, comment='Request executed', request_id=1683350122, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20695.9, stoplimit=0.0, sl=20735.9, tp=20675.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414552, order=20989311, volume=0.01, price=20711.2, bid=20711.2, ask=20713.3, comment='Request executed', request_id=1683350123, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20711.4, stoplimit=0.0, sl=20751.4, tp=20691.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414591, order=20989353, volume=0.01, price=20720.7, bid=20720.7, ask=20722.5, comment='Request executed', request_id=1683350124, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20723.7, stoplimit=0.0, sl=20763.7, tp=20703.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414639, order=20989399, volume=0.01, price=20708.2, bid=20708.2, ask=20710.3, comment='Request executed', request_id=1683350125, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20708.7, stoplimit=0.0, sl=20748.7, tp=20688.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414663, order=20989422, volume=0.01, price=20705.2, bid=20705.2, ask=20707.0, comment='Request executed', request_id=1683350126, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20704.7, stoplimit=0.0, sl=20744.7, tp=20684.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414710, order=20989489, volume=0.01, price=20709.7, bid=20709.7, ask=20711.8, comment='Request executed', request_id=1683350127, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20709.9, stoplimit=0.0, sl=20749.9, tp=20689.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414786, order=20989564, volume=0.01, price=20721.4, bid=20721.4, ask=20723.2, comment='Request executed', request_id=1683350128, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20719.9, stoplimit=0.0, sl=20759.9, tp=20699.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414880, order=20989679, volume=0.01, price=20712.7, bid=20712.7, ask=20714.5, comment='Request executed', request_id=1683350129, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20711.4, stoplimit=0.0, sl=20751.4, tp=20691.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414935, order=20989735, volume=0.01, price=20718.4, bid=20718.4, ask=20720.5, comment='Request executed', request_id=1683350130, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20718.4, stoplimit=0.0, sl=20758.4, tp=20698.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19414999, order=20989800, volume=0.01, price=20706.9, bid=20706.9, ask=20709.0, comment='Request executed', request_id=1683350131, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20706.4, stoplimit=0.0, sl=20746.4, tp=20686.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415036, order=20989846, volume=0.01, price=20704.7, bid=20704.7, ask=20706.5, comment='Request executed', request_id=1683350132, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20706.2, stoplimit=0.0, sl=20746.2, tp=20686.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415129, order=20989950, volume=0.01, price=20702.4, bid=20702.4, ask=20704.5, comment='Request executed', request_id=1683350133, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20702.2, stoplimit=0.0, sl=20742.2, tp=20682.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415182, order=20990014, volume=0.01, price=20723.7, bid=20723.7, ask=20725.5, comment='Request executed', request_id=1683350134, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20721.2, stoplimit=0.0, sl=20761.2, tp=20701.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415394, order=20990232, volume=0.01, price=20721.2, bid=20721.2, ask=20723.0, comment='Request executed', request_id=1683350135, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20721.4, stoplimit=0.0, sl=20761.4, tp=20701.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415458, order=20990295, volume=0.01, price=20722.4, bid=20722.4, ask=20724.2, comment='Request executed', request_id=1683350136, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20720.9, stoplimit=0.0, sl=20760.9, tp=20700.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415494, order=20990331, volume=0.01, price=20715.2, bid=20715.2, ask=20717.0, comment='Request executed', request_id=1683350137, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20715.2, stoplimit=0.0, sl=20755.2, tp=20695.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415606, order=20990444, volume=0.01, price=20690.9, bid=20690.9, ask=20692.7, comment='Request executed', request_id=1683350138, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20689.7, stoplimit=0.0, sl=20729.7, tp=20669.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19415742, order=20990579, volume=0.01, price=20668.2, bid=20668.2, ask=20670.3, comment='Request executed', request_id=1683350139, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20668.4, stoplimit=0.0, sl=20708.4, tp=20648.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416146, order=20991002, volume=0.01, price=20687.4, bid=20687.4, ask=20689.0, comment='Request executed', request_id=1683350140, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20687.7, stoplimit=0.0, sl=20727.7, tp=20667.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416185, order=20991043, volume=0.01, price=20689.9, bid=20689.9, ask=20692.0, comment='Request executed', request_id=1683350141, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20692.2, stoplimit=0.0, sl=20732.2, tp=20672.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416210, order=20991069, volume=0.01, price=20704.9, bid=20704.9, ask=20706.7, comment='Request executed', request_id=1683350142, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20704.9, stoplimit=0.0, sl=20744.9, tp=20684.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416263, order=20991126, volume=0.01, price=20691.2, bid=20691.2, ask=20693.3, comment='Request executed', request_id=1683350143, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20692.9, stoplimit=0.0, sl=20732.9, tp=20672.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416321, order=20991183, volume=0.01, price=20688.4, bid=20688.4, ask=20690.2, comment='Request executed', request_id=1683350144, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20687.9, stoplimit=0.0, sl=20727.9, tp=20667.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416381, order=20991241, volume=0.01, price=20692.9, bid=20692.9, ask=20695.0, comment='Request executed', request_id=1683350145, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20692.2, stoplimit=0.0, sl=20732.2, tp=20672.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416409, order=20991269, volume=0.01, price=20696.7, bid=20696.7, ask=20698.5, comment='Request executed', request_id=1683350146, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20696.4, stoplimit=0.0, sl=20736.4, tp=20676.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416443, order=20991302, volume=0.01, price=20707.7, bid=20707.7, ask=20709.5, comment='Request executed', request_id=1683350147, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20707.9, stoplimit=0.0, sl=20747.9, tp=20687.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416483, order=20991341, volume=0.01, price=20718.9, bid=20718.9, ask=20721.0, comment='Request executed', request_id=1683350148, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20717.9, stoplimit=0.0, sl=20757.9, tp=20697.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416569, order=20991424, volume=0.01, price=20743.9, bid=20743.9, ask=20745.7, comment='Request executed', request_id=1683350149, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20744.7, stoplimit=0.0, sl=20784.7, tp=20724.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416632, order=20991505, volume=0.01, price=20754.7, bid=20754.7, ask=20756.5, comment='Request executed', request_id=1683350150, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20754.9, stoplimit=0.0, sl=20794.9, tp=20734.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416720, order=20991593, volume=0.01, price=20753.9, bid=20753.9, ask=20755.7, comment='Request executed', request_id=1683350151, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20753.9, stoplimit=0.0, sl=20793.9, tp=20733.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416801, order=20991671, volume=0.01, price=20754.4, bid=20754.4, ask=20756.0, comment='Request executed', request_id=1683350152, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20754.4, stoplimit=0.0, sl=20794.4, tp=20734.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416894, order=20991764, volume=0.01, price=20770.4, bid=20770.4, ask=20772.5, comment='Request executed', request_id=1683350153, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20770.2, stoplimit=0.0, sl=20810.2, tp=20750.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19416917, order=20991805, volume=0.01, price=20768.7, bid=20768.7, ask=20770.8, comment='Request executed', request_id=1683350154, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20768.9, stoplimit=0.0, sl=20808.9, tp=20748.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417036, order=20991922, volume=0.01, price=20789.9, bid=20789.9, ask=20791.7, comment='Request executed', request_id=1683350155, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20789.7, stoplimit=0.0, sl=20829.7, tp=20769.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417069, order=20991957, volume=0.01, price=20763.4, bid=20763.4, ask=20765.2, comment='Request executed', request_id=1683350156, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20762.2, stoplimit=0.0, sl=20802.2, tp=20742.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417092, order=20991980, volume=0.01, price=20764.7, bid=20764.7, ask=20766.5, comment='Request executed', request_id=1683350157, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20764.9, stoplimit=0.0, sl=20804.9, tp=20744.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417147, order=20992033, volume=0.01, price=20771.4, bid=20771.4, ask=20773.2, comment='Request executed', request_id=1683350158, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20771.4, stoplimit=0.0, sl=20811.4, tp=20751.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417182, order=20992068, volume=0.01, price=20765.2, bid=20765.2, ask=20767.0, comment='Request executed', request_id=1683350159, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20766.2, stoplimit=0.0, sl=20806.2, tp=20746.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417207, order=20992093, volume=0.01, price=20764.9, bid=20764.9, ask=20766.7, comment='Request executed', request_id=1683350160, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20764.9, stoplimit=0.0, sl=20804.9, tp=20744.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417244, order=20992131, volume=0.01, price=20774.7, bid=20774.7, ask=20776.5, comment='Request executed', request_id=1683350161, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20774.9, stoplimit=0.0, sl=20814.9, tp=20754.9, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417334, order=20992226, volume=0.01, price=20771.9, bid=20771.9, ask=20773.7, comment='Request executed', request_id=1683350162, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20770.7, stoplimit=0.0, sl=20810.7, tp=20750.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417352, order=20992245, volume=0.01, price=20772.2, bid=20772.2, ask=20774.0, comment='Request executed', request_id=1683350163, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20772.2, stoplimit=0.0, sl=20812.2, tp=20752.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417383, order=20992277, volume=0.01, price=20758.9, bid=20758.9, ask=20760.7, comment='Request executed', request_id=1683350164, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20759.4, stoplimit=0.0, sl=20799.4, tp=20739.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417400, order=20992295, volume=0.01, price=20764.9, bid=20764.9, ask=20766.7, comment='Request executed', request_id=1683350165, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20765.4, stoplimit=0.0, sl=20805.4, tp=20745.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417802, order=20992698, volume=0.01, price=20760.7, bid=20760.7, ask=20762.8, comment='Request executed', request_id=1683350166, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20761.4, stoplimit=0.0, sl=20801.4, tp=20741.4, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417826, order=20992722, volume=0.01, price=20775.7, bid=20775.7, ask=20777.5, comment='Request executed', request_id=1683350167, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20775.7, stoplimit=0.0, sl=20815.7, tp=20755.7, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=19417852, order=20992750, volume=0.01, price=20767.4, bid=20767.4, ask=20769.2, comment='Request executed', request_id=1683350168, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='US100', volume=0.01, price=20767.2, stoplimit=0.0, sl=20807.2, tp=20747.2, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_MA10, MA20' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# ...
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
# Dữ liệu đã được xử lý
# Không tìm thấy dữ liệu cho hash 'OG_FX_MA10, MA20'.
