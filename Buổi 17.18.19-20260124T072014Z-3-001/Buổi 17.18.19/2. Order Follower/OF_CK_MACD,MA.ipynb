# %%
# Hàm để đặt một lệnh mua
import requests
import os

def orderChungKhoan(data):
    
    # Lấy dữ liệu từ từ điển
    datetime = data['Datetime']
    open_price = data['Open']
    close_price = data['Close']
    volume = data['Volume']
    sma = data['SMA']
    short_ema = data['short_ema']
    long_ema = data['long_ema']
    macd = data['MACD']
    signal_line = data['Signal_Line']
    buy_signal = data['Buy_Signal']
    
    sell_signal = data['Sell_Signal']
    symbol = data['Symbol']
    insertdate = data['Insertdate']
    
    order = None

    # http://127.0.0.1:8000/newOrder?
    
    # instrumentID=ACB&market=VN&buySell=B&orderType=ATO&price=0&quantity=100&account=2654251&stopOrder=false&stopPrice=0&stopStep=0&lossStep=0&profitStep=0&deviceId=Local%20Area%20Connection%2A%201%3A18-CC-18-C9-CB-6B%7CLocal%20Area%20Connection%2A%202%3A1A-CC-18-C9-CB-6A%7CWi-Fi%3A18-CC-18-C9-CB-6A%7CBluetooth%20Network%20Connection%3A18-CC-18-C9-CB-6E&userAgent=Python%2F3.11.6%28Windows-10-10.0.19045-SP0%29%3B%20ssi-fctrading%2F2.4.2

    try:
        # Trường họp BUY
        if buy_signal == 'True':
            # URL đã dựng API để sử dụng API
            base_url = "http://127.0.0.1:8000/newOrder"

            # Đưa các tham số vào đúng format lệnh mua
            params = {
                "instrumentID": symbol,
                "market": "VN",
                "buySell": "B",
                "orderType": "ATO",
                "price": 0,
                "quantity": 100,
                "account": 2654251,
                "stopOrder": "false",
                "stopPrice": 0,
                "stopStep": 0,
                "lossStep": 0,
                "profitStep": 0,
                "deviceId": "Local Area Connection 2:00-FF-D6-53-51-3D|Ethernet:A4-4C-C8-1F-0A-34|HotspotShield Network Adapter:00-FF-1B-37-F1-B2|Local Area Connection* 1:F8-34-41-52-B6-98|Local Area Connection* 10:FA-34-41-52-B6-97|Ethernet 2:00-09-0F-FE-00-01|Wi-Fi:F8-34-41-52-B6-97|Bluetooth Network Connection:F8-34-41-52-B6-9B",
                "userAgent": "Python/3.11.6(Windows-10-10.0.17763-SP0); ssi-fctrading/2.4.2"
            }

            # Đẩy dữ liệu lên API
            response = requests.get(base_url, params=params)

            # Xử lý kết quả trả về
            if response.status_code == 200:
                data = response.json()["data"]
                print(f"The stock BUY for account 2654251 is {data}")
            else:
                print(f"Error connecting to API: {response.status_code}")
        
        # Trường hợp SELL        
        elif sell_signal == 'True':        
            # URL đã dựng API để sử dụng API
            base_url = "http://127.0.0.1:8000/newOrder"

            # Đưa các tham số vào đúng format lệnh mua
            params = {
                "instrumentID": symbol,
                "market": "VN",
                "buySell": "S",
                "orderType": "ATO",
                "price": 0,
                "quantity": 100,
                "account": 2654251,
                "stopOrder": "false",
                "stopPrice": 0,
                "stopStep": 0,
                "lossStep": 0,
                "profitStep": 0,
                "deviceId": "Local Area Connection* 1:18-CC-18-C9-CB-6B|Local Area Connection* 2:1A-CC-18-C9-CB-6A|Wi-Fi:18-CC-18-C9-CB-6A|Bluetooth Network Connection:18-CC-18-C9-CB-6E",
                "userAgent": "Python/3.11.6(Windows-10-10.0.19045-SP0); ssi-fctrading/2.4.2"
            }

            # Đẩy dữ liệu lên API
            response = requests.get(base_url, params=params)

            # Xử lý kết quả trả về
            if response.status_code == 200:
                data = response.json()["data"]
                print(f"The stock SELL for account 2654251 is {data}")
            else:
                print(f"Error connecting to API: {response.status_code}")
            
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
import redis
from datetime import datetime, timedelta

def entryChungKhoan(hash):
    # Xử lý dữ liệu ở đây
    print("Dữ liệu đã được xử lý", datetime.now())

    # Tạo kết nối Redis
    r = redis.Redis(host='localhost', port=6379, db=0)

    # Hash key
    hash_key = hash

    # Đọc dữ liệu từ hash
    data = r.hgetall(hash_key)
    
    if data:
        # Chuyển đổi dữ liệu từ bytes sang chuỗi nếu cần
        data = {key.decode('utf-8'): value.decode('utf-8') for key, value in data.items()}
        # Xử lý dữ liệu
        orderChungKhoan(data)
        # Xóa hash sau khi xử lý
        r.delete(hash_key)
        print(f"Hash '{hash_key}' đã được xóa khỏi Redis.")
    else:
        print(f"Không tìm thấy dữ liệu cho hash '{hash_key}'.")

# %%
from datetime import datetime, timedelta
import schedule
import time

def schedule_ChungKhoan():
    entryChungKhoan('OG_CK_MACD,MA')

# Lên lịch hàm scan_market để chạy mỗi 15 phút
schedule.every(10).seconds.do(schedule_ChungKhoan)

while True:
    schedule.run_pending()  # Hàm này được gọi liên tục để kiểm tra xem có công việc nào đã đến thời gian cần thực hiện hay không
    time.sleep(10)
# Out:
# Dữ liệu đã được xử lý 2024-07-11 21:17:51.501294
# The stock BUY for account 2654251 is {'requestID': '40668968', 'requestData': {'instrumentID': 'STB', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
# Hash 'OG_CK_MACD,MA' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2024-07-11 21:18:03.864126
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:18:13.869428
# The stock BUY for account 2654251 is {'requestID': '68653636', 'requestData': {'instrumentID': 'STB', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
# Hash 'OG_CK_MACD,MA' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2024-07-11 21:18:25.151935
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:18:35.155522
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:18:45.162271
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:18:55.168292
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:19:05.172315
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:19:15.176520
# The stock BUY for account 2654251 is {'requestID': '5619194', 'requestData': {'instrumentID': 'STB', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
# Hash 'OG_CK_MACD,MA' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2024-07-11 21:19:27.180091
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:19:37.183449
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:19:47.186459
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:19:57.189678
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:20:07.203787
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:20:17.215381
# The stock BUY for account 2654251 is {'requestID': '99553801', 'requestData': {'instrumentID': 'STB', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
# Hash 'OG_CK_MACD,MA' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2024-07-11 21:20:29.051936
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:20:39.056028
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:20:49.060030
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:20:59.062464
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:21:09.064700
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:21:19.068313
# The stock BUY for account 2654251 is {'requestID': '1240578', 'requestData': {'instrumentID': 'STB', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
# Hash 'OG_CK_MACD,MA' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2024-07-11 21:21:29.835121
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:21:39.837779
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:21:49.840568
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:21:59.843812
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:22:09.846887
# The stock BUY for account 2654251 is {'requestID': '29175935', 'requestData': {'instrumentID': 'STB', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
# Hash 'OG_CK_MACD,MA' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2024-07-11 21:22:21.032031
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:22:31.047482
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:22:41.053461
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:22:51.058921
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21:23:01.062469
# Không tìm thấy dữ liệu cho hash 'OG_CK_MACD,MA'.
# Dữ liệu đã được xử lý 2024-07-11 21