# %%
import sys
sys.path.append('../Common/')

import CommonBinance

# %%
symbol = 'BTCUSDT'
from_date = '2024-05-01'
to_date = '2024-06-03'
data = CommonBinance.CommonBinance.loaddataBinance_FromTo_Split(symbol, from_date, to_date, '1m')
data
# Out:
#                Datetime      Open      High       Low     Close    Volume
# 0   2024-05-01 00:00:00  60672.01  60750.00  60660.98  60742.33  55.30759
# 1   2024-05-01 00:01:00  60742.33  60779.52  60721.76  60757.86  15.62630
# 2   2024-05-01 00:02:00  60757.87  60757.87  60675.20  60678.13  38.57373
# 3   2024-05-01 00:03:00  60678.13  60709.96  60675.21  60709.96   9.00795
# 4   2024-05-01 00:04:00  60709.96  60728.00  60688.39  60688.39  27.67657
# ..                  ...       ...       ...       ...       ...       ...
# 995 2024-06-03 07:55:00  68849.99  68850.00  68849.99  68850.00   2.24372
# 996 2024-06-03 07:56:00  68849.99  68875.16  68849.99  68875.16   9.39467
# 997 2024-06-03 07:57:00  68875.16  68875.16  68868.00  68868.00  10.45962
# 998 2024-06-03 07:58:00  68868.00  68868.01  68868.00  68868.01   4.04765
# 999 2024-06-03 07:59:00  68868.00  68906.70  68868.00  68906.70   8.59919
#
# [48000 rows x 6 columns]
