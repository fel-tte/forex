# %% [markdown]
# # Thuc hanh voi chien luoc cua cac ban
#
# 1. Xay dung OG voi chien luoc cua cac ban voi BTCUSD voi khung thoi gian 1p
#
# Neu chua co chien luoc thi
#
# 2. Xay dung OG voi chien luoc ARIMA, MA10 va MA20:
# - Buy khi gia du doan nam tren gia thuc te va MA10 nam tren MA20
# - Sell khi gia du doan nam duoi gia thuc te va MA10 nam duoi MA20

# %% [markdown]
# # Tinh toan xac suat vao lenh thanh cong
#
# - Khi vao lenh Buy => Thi gia ke tiep tang hon so voi gia hien tai
# - Khi vao lenh Sell => Thi gia ke tiep giam hon so voi gia hien tai
