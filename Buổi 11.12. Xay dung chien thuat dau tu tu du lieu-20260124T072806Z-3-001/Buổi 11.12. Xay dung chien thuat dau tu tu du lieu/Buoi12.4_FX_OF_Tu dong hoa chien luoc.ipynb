# %%
# Hàm để đặt một lệnh mua
import requests
import os
import MetaTrader5 as mt5

def orderForex(data):
	
	# Lấy dữ liệu từ từ điển
	buy_signal = data['Buy_Signal']    
	sell_signal = data['Sell_Signal']
	symbol = data['Symbol']
	insertdate = data['Insertdate']
	
	# if not mt5.initialize(login=48333595, password='9$R#9ht@', server='HFMarketsGlobal-Demo'): # Hotforex Real
	# if not mt5.initialize(login=10138239, password='xiVUPi4J', server='mt5-b2broker-metatrader5.fastmt-b.net:443'): # B2Brocker Demo
	# if not mt5.initialize(login=51524754, password='I2dmjFp5', server='mt5-demo.icmarkets.com'): # ICMarket Demo
	# if not mt5.initialize(login=7174192, password='NttZS95a', server='ICMarketsSC-MT5-2.icmarkets.com'): # ICMarket Real
	# if not mt5.initialize(login=115407068, password='123456Qaz1!', server='mt5trial6.exness.com:443'): # Exness Trial    
	# if not mt5.initialize(login=103466790, password='123456Qaz1!', server='Exness-MT5Real15'): # Exness Real  
	# if not mt5.initialize(login=3928, password='!Od52b03', server='XSFintech-DEMO'): # XS  
	if not mt5.initialize(login=6338576, password='123456Qaz1!', server='OANDA-Demo-1'): # Oanda Demo  
		print("Initialize() failed, error code =", mt5.last_error())
		quit()
	else:
		if(buy_signal == 'True'): # Do data la du lieu tu Redis la string
			lot = 0.01  # Số lượng lô mà bạn muốn mua
			if not mt5.symbol_select(symbol, True): # 
				print(f"Failed to select {symbol}, error code =", mt5.last_error())
				return

			symbol_info = mt5.symbol_info(symbol)
			if symbol_info is None:
				print(f"{symbol} not found")
				return
			
			point = symbol_info.point
			price = mt5.symbol_info_tick(symbol).ask
			deviation = 20  # Độ lệch giá cho phép

			request = {
				"action": mt5.TRADE_ACTION_DEAL,
				"symbol": symbol,
				"volume": lot,
				"type": mt5.ORDER_TYPE_BUY,
				"price": price,
				"sl": price - 4000 * point,  # Lệnh dừng lỗ (Stop Loss)
				"tp": price + 200 * point,  # Lệnh chốt lời (Take Profit)
				"deviation": deviation,
				"magic": 234000,
				"comment": "python script open",
				"type_time": mt5.ORDER_TIME_GTC,
				# "type_filling": mt5.ORDER_FILLING_IOC,
				"type_filling": mt5.ORDER_FILLING_FOK,
				
			}

			result = mt5.order_send(request)
			if result.retcode != mt5.TRADE_RETCODE_DONE:
				print("Failed to send order :", result.retcode, result._asdict())
			else:
				print("Order placed BUY successfully!", result)

			# Đóng kết nối với MT5
			mt5.shutdown()

		elif (sell_signal == 'True'):
			lot = 0.01  # Số lượng lô bạn muốn bán
			if not mt5.symbol_select(symbol, True):
				print(f"Failed to select {symbol}, error code =", mt5.last_error())
				return

			symbol_info = mt5.symbol_info(symbol)
			if symbol_info is None:
				print(f"{symbol} not found")
				return
			
			point = symbol_info.point
			price = mt5.symbol_info_tick(symbol).bid  # Sử dụng giá bid cho lệnh bán
			deviation = 20  # Độ lệch giá cho phép

			request = {
				"action": mt5.TRADE_ACTION_DEAL,
				"symbol": symbol,
				"volume": lot,
				"type": mt5.ORDER_TYPE_SELL,
				"price": price,
				"sl": price + 4000 * point,  # Lệnh dừng lỗ (Stop Loss) cho lệnh bán
				"tp": price - 200 * point,  # Lệnh chốt lời (Take Profit) cho lệnh bán
				"deviation": deviation,
				"magic": 234000,
				"comment": "python script open",
				"type_time": mt5.ORDER_TIME_GTC,
				# "type_filling": mt5.ORDER_FILLING_IOC,
				"type_filling": mt5.ORDER_FILLING_FOK,
				# ORDER_FILLING_RETURN 
			}

			result = mt5.order_send(request)
			if result.retcode != mt5.TRADE_RETCODE_DONE:
				print("Failed to send order :", result.retcode, result._asdict())
			else:
				print("Order placed SELL successfully!", result)

			# Đóng kết nối với MT5
			mt5.shutdown()

# %%
import redis
from datetime import datetime, timedelta

def entryForex(hash):
	# Xử lý dữ liệu ở đây
	print("Dữ liệu đã được xử lý", datetime.now())

	# Tạo kết nối Redis
	r = redis.Redis(host='localhost', port=6379, db=9)

	# Hash key
	hash_key = hash

	# Đọc dữ liệu từ hash
	data = r.hgetall(hash_key)
	
	if data:
		# Chuyển đổi dữ liệu từ bytes sang chuỗi nếu cần
		data = {key.decode('utf-8'): value.decode('utf-8') for key, value in data.items()}
		# Xử lý dữ liệu
		orderForex(data)
		# Xóa hash sau khi xử lý
		r.delete(hash_key)
		print(f"Hash '{hash_key}' đã được xóa khỏi Redis.")
	else:
		print(f"Không tìm thấy dữ liệu cho hash '{hash_key}'.")

# %%
from datetime import datetime, timedelta
import schedule
import time

def schedule_Forex():
	entryForex('OG_FX_Arima, Momentum, RSI_K13') # OG_FX_Arima, Momentum, RSI_K9

# Lên lịch hàm scan_market để chạy mỗi 15 phút
schedule.every(5).seconds.do(schedule_Forex)

while True:
	schedule.run_pending()  # Hàm này được gọi liên tục để kiểm tra xem có công việc nào đã đến thời gian cần thực hiện hay không
	# time.sleep(1)
# Out:
# Dữ liệu đã được xử lý 2025-10-22 22:03:56.531973
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:03.553050
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=32504992, order=30597045, volume=0.01, price=1.16146, bid=1.16146, ask=1.16154, comment='Request executed', request_id=1362757515, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.16144, stoplimit=0.0, sl=1.20144, tp=1.15944, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:04:10.855082
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:17.892631
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:24.908232
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:31.946779
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:38.980306
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:46.010458
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:04:53.039116
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:00.079285
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:07.112919
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=32505024, order=30597077, volume=0.01, price=1.1612, bid=1.1612, ask=1.16126, comment='Request executed', request_id=1362757516, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.16119, stoplimit=0.0, sl=1.20119, tp=1.15919, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:05:14.413403
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:21.439351
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:28.455147
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:35.480114
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:42.512126
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:49.538952
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:05:56.613562
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:03.649438
# Order placed BUY successfully! OrderSendResult(retcode=10009, deal=32505042, order=30597093, volume=0.01, price=1.16116, bid=1.16107, ask=1.16116, comment='Request executed', request_id=1362757517, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.1611799999999999, stoplimit=0.0, sl=1.1211799999999998, tp=1.1631799999999999, deviation=20, type=0, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:06:10.995577
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:18.028060
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:25.068351
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:32.091215
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:39.116268
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:46.158531
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:06:53.191539
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:00.230868
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:07.264841
# Order placed BUY successfully! OrderSendResult(retcode=10009, deal=32505059, order=30597111, volume=0.01, price=1.16115, bid=1.16106, ask=1.16115, comment='Request executed', request_id=1362757518, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.16115, stoplimit=0.0, sl=1.1211499999999999, tp=1.16315, deviation=20, type=0, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:07:14.662227
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:21.686030
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:28.728066
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:35.767208
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:42.797449
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:49.834028
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:07:56.868128
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:03.896181
# Order placed BUY successfully! OrderSendResult(retcode=10009, deal=32505086, order=30597136, volume=0.01, price=1.1611, bid=1.16101, ask=1.1611, comment='Request executed', request_id=1362757519, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.1611, stoplimit=0.0, sl=1.1211, tp=1.1631, deviation=20, type=0, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:08:11.430308
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:18.452485
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:25.487091
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:32.534249
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:39.560677
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:46.580174
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:08:53.622287
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:00.669218
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:07.705126
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=32505117, order=30597168, volume=0.01, price=1.16111, bid=1.16111, ask=1.1612, comment='Request executed', request_id=1362757520, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.1611, stoplimit=0.0, sl=1.2011, tp=1.1591, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:09:15.243839
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:22.271825
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:29.284003
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:36.319690
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:43.355452
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:50.379507
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:09:57.411389
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:10:04.441375
# Order placed SELL successfully! OrderSendResult(retcode=10009, deal=32505143, order=30597192, volume=0.01, price=1.16119, bid=1.16119, ask=1.16127, comment='Request executed', request_id=1362757521, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD.sml', volume=0.01, price=1.16119, stoplimit=0.0, sl=1.20119, tp=1.15919, deviation=20, type=1, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))
# Hash 'OG_FX_Arima, Momentum, RSI_K13' đã được xóa khỏi Redis.
# Dữ liệu đã được xử lý 2025-10-22 22:10:11.735940
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:10:18.768909
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:10:25.809044
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
# Dữ liệu đã được xử lý 2025-10-22 22:10:32.842989
# Không tìm thấy dữ liệu cho hash 'OG_FX_Arima, Momentum, RSI_K13'.
