# %%
import requests

url = "http://127.0.0.1:8000/getOtp"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(f"Verify code for account 2654251 is {data}")
else:
    print(f"Error connecting to API: {response.status_code}")
# Out:
# Verify code for account 2654251 is {'message': 'Success', 'status': 200}

# %%
import requests

url = "http://127.0.0.1:8000/verifyCode?code=207189"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(f"Verify code for account 2654251 is {data}")
else:
    print(f"Error connecting to API: {response.status_code}")
# Out:
# Verify code for account 2654251 is eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....fPpOz3IUC3kNXfFdWcMbvyTr9MEuLte5b-Jdfov445DK7DV5bq2z0OPBP9XepWLu4zyxIhR2m_QEu49FTUSSeEDNWUdCBLiJe2hAymMRK7ohE8NKUdIbxk9Yiqi_kw_6RZySozYRMfB5jgwVyrIGszVtZ9WY-achAs1fgytcpEPdkSH-7lGYY0SAsQEkoePBhaAVCLexsCgMCkiYUSGZOCONI1NHNBEobe7RjHMDXz_xDfk-Qd22i5VjJSl1s-Gotl5E_ZeCxIPYy1iyXwn9i_RKKZydCI3iqvH_tPOF5oOHcuwHaIc_EmN9jULdqORZuTY4b-St3YROpa7j15MY-A

# %%
import requests

# Base URL for the API
# http://127.0.0.1:8000/newOrder?instrumentID=VCB&market=VN&buySell=B&orderType=ATO&price=0&quantity=100&account=2654251&stopOrder=false&stopPrice=0&stopStep=0&lossStep=0&profitStep=0&deviceId=Local%20Area%20Connection%2A%201%3A18-CC-18-C9-CB-6B%7CLocal%20Area%20Connection%2A%202%3A1A-CC-18-C9-CB-6A%7CWi-Fi%3A18-CC-18-C9-CB-6A%7CBluetooth%20Network%20Connection%3A18-CC-18-C9-CB-6E&userAgent=Python%2F3.11.6%28Windows-10-10.0.19045-SP0%29%3B%20ssi-fctrading%2F2.4.2

base_url = "http://127.0.0.1:8000/newOrder"

# Parameters for the API request
params = {
    "instrumentID": "QBS",
    "market": "VN",
    "buySell": "B",
    "orderType": "ATO",
    "price": 0,
    "quantity": 100,
    "account": 2654251,
    "stopOrder": "false",
    "stopPrice": 0,
    "stopStep": 0,
    "lossStep": 0,
    "profitStep": 0,
    "deviceId": "Local Area Connection* 1:18-CC-18-C9-CB-6B|Local Area Connection* 2:1A-CC-18-C9-CB-6A|Wi-Fi:18-CC-18-C9-CB-6A|Bluetooth Network Connection:18-CC-18-C9-CB-6E",
    "userAgent": "Python/3.11.6(Windows-10-10.0.19045-SP0); ssi-fctrading/2.4.2"
}

# Sending the GET request to the API
response = requests.get(base_url, params=params)

# Print the raw response
print(response)

# Handling the response
if response.status_code == 200:
    data = response.json()["data"]
    print(f"The stock order for account 2654251 is {data}")
else:
    print(f"Error connecting to API: {response.status_code}")
# Out:
# <Response [200]>
# The stock order for account 2654251 is {'requestID': '59542628', 'requestData': {'instrumentID': 'QBS', 'market': 'VN', 'buySell': 'B', 'orderType': 'ATO', 'channelID': 'TA', 'price': 0.0, 'quantity': 100, 'account': '2654251', 'stopOrder': False, 'stopPrice': 0.0, 'stopType': '', 'stopStep': 0.0, 'lossStep': 0.0, 'profitStep': 0.0}}
