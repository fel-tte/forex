# %% [markdown]
# # K6 Bai 1

# %% [markdown]
# Markdown

# %%
print('K6*2 lan 2')
# Out:
# K6*2 lan 2

# %% [markdown]
# Font nho

# %% [markdown]
# # Font lon

# %% [markdown]
# ## Font nho hon xiu

# %% [markdown]
# ### Font nho hon xiu nua

# %% [markdown]
# #### Nho xiu

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # Ghi chu K9

# %%
print('Hello K9')
# Out:
# Hello K9

# %% [markdown]
# # Ghu chu abc

# %%
print('Ghi chu ABC')
# Out:
# Ghi chu ABC

# %% [markdown]
# # Ghi chu

# %%
print(1)
# Out:
# 1
